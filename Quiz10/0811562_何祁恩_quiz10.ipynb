# %% [markdown]
# # Rules
# * Internet and Books are ALLOWED
# * Name your file as following: StudentID_ChineseName/EnglishName_quiz
# * Extension of your file or your file type should be .py

# %% [markdown]
# ## Load the iris data

# %%
from sklearn.datasets import load_iris

data = load_iris()

X = data.data

y = data.target

# %% [markdown]
# - Splitting the dataset into training data and test data with training size of 70%. **Set random state to 50.**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 50, test_size = 0.3)

# %% [markdown]
# - Using decision tree classifier package from sklearn with parameter max_depth of 3 (look it up).

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth = 3)
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# - Predict the rate of accuracy with test data and print it.

# %%
from sklearn.metrics import accuracy_score
y_pred = clf.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred=y_pred))
# Out:
# 0.9555555555555556

# %% [markdown]
# :- (Bonus 20 points) Visualize the decision tree. Your result should be similar to something like this. You can plot it or save it as an image. If you do the latter, please submit your code along with the picture in a zip file.
#
# ![diabetes.png](data:image/png;base64,...)

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

clf_all = DecisionTreeClassifier().fit(X_train,y_train)
plt.figure(figsize = (18, 12))
plot_tree(clf_all,rounded = True,filled = True)
plt.show()
